# %% [markdown]
# ### 자신이 자주 사용하는 코드를 라이브러리화 하쟈!!
# ### 그리디 , 구현 ,DFS/BFS가 가장 많이 나온다!!

# %% [markdown]
# ### 시간 복잡도 : 수행 시간 분석
# ### 공간 복잡도 : 메모리 사용량 분석
# ### >>> 복잡도가 낮을수록 좋은 알고리즘
# ![1.PNG](attachment:1.PNG)
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# ## <파이썬 수행 시간 측정 방법>

# %%
import time
start_time = time.time() # 측정 시작

# 프로그램 소스코드
end_time = time.time() # 측정 종료
print("time:", end_time - start_time) # 수행 시간 출력
# Out:
# time: 0.0

# %% [markdown]
# ## <선택 정렬과 기본 정렬 라이브러리의 수행 시간 비교>

# %%
from random import randint
import time

# 배열에 10,000개의 정수를 삽입
array = []
for _ in range(10000):
    array.append(randint(1, 100)) # 1부터 100 사이의 랜덤한 정수

# 선택 정렬 프로그램 성능 측정
start_time = time.time()

# 선택 정렬 프로그램 소스코드
for i in range(len(array)):
    min_index = i # 가장 작은 원소의 인덱스
    for j in range(i + 1, len(array)):
        if array[min_index] > array[j]:
            min_index = j
    array[i], array[min_index] = array[min_index], array[i] # 스와프

end_time = time.time() # 측정 종료
print("선택 정렬 성능 측정:", end_time - start_time) # 수행 시간 출력

# 배열을 다시 무작위 데이터로 초기화
array = []
for _ in range(10000):
    array.append(randint(1, 100)) # 1부터 100 사이의 랜덤한 정수

# 기본 정렬 라이브러리 성능 측정
start_time = time.time()

# 기본 정렬 라이브러리 사용
array.sort()

end_time = time.time() # 측정 종료
print("기본 정렬 라이브러리 성능 측정:", end_time - start_time) # 수행 시간 출력
# Out:
# 선택 정렬 성능 측정: 7.321367025375366
# 기본 정렬 라이브러리 성능 측정: 0.0015048980712890625

# %% [markdown]
# ## < input >

# %%
a = int(input(""))  ##  모험가의 수 받고
b,c = map(int, input("").split())  ##  모험가의 수 받고
num_list = list(map(int, input("").split()))  #1차원 배열 입력받기!

print("\n",a,"\n")
print(b,c,"\n")
print(num_list)
# Out:
# 4
# 4 5
# 공포도 입력:4 5 6
#
#  4
#
# 4 5
#
# [4, 5, 6]

# %% [markdown]
# ## <1차원 리스트>

# %%
#arr = ["F", "D", "A", "C", "A", "C", "F", "B", "C", "E", "D", "C", "F", "A", "B", "E", "F", "E"]
arr = [1,2,2,7,5,4,1,4,6,8,7,5,6]
print(arr)

arr = list(set(arr))
print("배열 중복 제거",arr)

arr.sort(reverse=False) ##공포도 오름차순 정렬
print("오름차순 정렬",arr)

arr.sort(reverse=True) ##공포도 내림차순 정렬
print("내림차순 정렬",arr)
# Out:
# [1, 2, 2, 7, 5, 4, 1, 4, 6, 8, 7, 5, 6]
# 배열 중복 제거 [1, 2, 4, 5, 6, 7, 8]
# 오름차순 정렬 [1, 2, 4, 5, 6, 7, 8]
# 내림차순 정렬 [8, 7, 6, 5, 4, 2, 1]

# %% [markdown]
# ## <2차원 리스트>

# %%
## n X n
n = int(input("")) 
maps = [list(map(int, input().split(' '))) for _ in range(n)] 
maps
# Out:
# 5
# 4 5 4 6 4
# 4 7 5 2 1
# 2 1 3 4 5
# 5 6 8 7 2
# 1 2 3 4 9
# [[4, 5, 4, 6, 4],
#  [4, 7, 5, 2, 1],
#  [2, 1, 3, 4, 5],
#  [5, 6, 8, 7, 2],
#  [1, 2, 3, 4, 9]]
