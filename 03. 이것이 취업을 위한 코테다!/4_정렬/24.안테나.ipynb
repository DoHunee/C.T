# %% [markdown]
# ![24.PNG](attachment:24.PNG)

# %% [markdown]
# ## 답지 ver

# %%
n = int(input())
a = list(map(int, input().split()))
a.sort()

# 중간값(median)을 출력
print(a[(n - 1) // 2])
# Out:
# 4
# 5 1 7 9
# 5
