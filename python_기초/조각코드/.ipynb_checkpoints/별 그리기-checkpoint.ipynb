# %% [markdown]
# ## 프로그램2:마름모 모양 출력 (while문 사용)
# ## 코드 이해하기
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
i,k=0,0

i=0
while i < 9:
    if i < 5:
        k=0
        while k < 4-i:
            print('  ',end='')
            k+=1
        k=0
    
        while k < i*2+1:
            print('\u2605',end='')
            k+=1
     
     
        #별 개수 증가
    else:
        k=0
        
        while k < i-4:
            print('  ',end='')
            k+=1
                
        k=0    
        while k < (9-i)*2-1:
            print('\u2605',end='')
            k+=1
            
    print()
    i +=1
# Out:
#         ★
#       ★★★
#     ★★★★★
#   ★★★★★★★
# ★★★★★★★★★
#   ★★★★★★★
#     ★★★★★
#       ★★★
#         ★

# %%
i,k=0,0

i=0
while i < 9:
    if i < 5:
        k=0
        while k < 4-i:
            print('  ',end='')
            k+=1
        k=0
    
        while k < i*2+1:
            print('\u2605',end='')
            k+=1
     
     
        #별 개수 증가
    else:
        k=0
        
        while k < i-4:
            print('  ',end='')
            k+=1
                
        k=0    
        while k < (9-i)*2-1:
            print('\u2605',end='')
            k+=1
            
    print()
    i +=1
# Out:
#         ★
#       ★★★
#     ★★★★★
#   ★★★★★★★
# ★★★★★★★★★
#   ★★★★★★★
#     ★★★★★
#       ★★★
#         ★

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i,k=0,0

i=0
while i < 9:
    if i < 5:
        k=0
        while k < 4-i:
            print('  ',end='')
            k+=1
        k=0
    
        while k < i*2+1:
            print('\u2605',end='')
            k+=1
     
     
        #별 개수 증가
    else:
        k=0
        
        while k < i-4:
            print('  ',end='')
            k+=1
                
        k=0    
        while k < (9-i)*2-1:
            print('\u2665',end='')
            k+=1
            
    print()
    i +=1
# Out:
#         ★
#       ★★★
#     ★★★★★
#   ★★★★★★★
# ★★★★★★★★★
#   ♥♥♥♥♥♥♥
#     ♥♥♥♥♥
#       ♥♥♥
#         ♥

# %% [markdown]
# ## 모래시계 모양 해보기! >> TEST

# %% [markdown]
# ## 다른 다양한 모양

# %%
for i in range(0,11):
    if i <5:
        for k in range(0,i):   ##i=1 k=0
            print("  ",end='')
            
        for k in range(0,(6-i)*2-1):    ##-2*i+9
            print("\u2605",end='')
    else:
        for k in range(0,10-i):
            print("  ",end='')
        
        for k in range(0,i*2-9):
            print("\u2605",end="")
            
    print()
# Out:
# ★★★★★★★★★★★
#   ★★★★★★★★★
#     ★★★★★★★
#       ★★★★★
#         ★★★
#           ★
#         ★★★
#       ★★★★★
#     ★★★★★★★
#   ★★★★★★★★★
# ★★★★★★★★★★★

# %%
for i in range(0,9):
    if i <5:
        for k in range(0,i):  ## i=1  k=0
            print("  ",end='')
        for k in range(0,-2*i+9):  ## -2*i+9
            print("\u2605",end='')
    else:
        for k in range(0,8-i):
            print("  ",end='')
        
        for k in range(0,2*i-7):
            print("\u2605",end="")
            
    print()
# Out:
# ★★★★★★★★★
#   ★★★★★★★
#     ★★★★★
#       ★★★
#         ★
#       ★★★
#     ★★★★★
#   ★★★★★★★
# ★★★★★★★★★

# %% [markdown]
# # 구글링ver

# %%
num = int(input("")) 

space = num - 2 
for i in range(2*num-1):
    if i < num:
        print("  "*i+"\u2605"*(2*(num-i)-1)) 
    else :
        print("  "*space+"\u2605"*(((2*num)-1)-(2*space))) 
        space = space - 1
# Out:
# 5
# ★★★★★★★★★
#   ★★★★★★★
#     ★★★★★
#       ★★★
#         ★
#       ★★★
#     ★★★★★
#   ★★★★★★★
# ★★★★★★★★★

# %% [markdown]
# ## 과제1  눕힌 모래시계

# %%
n = int(input())
star = '\u2605'
#star = ''
space = '  '

for i in range(0, n):
    print(star * (i + 1) + space * (n - (i + 1)) + space * (n - (i + 1)) + star * (i + 1))

for i in range(n-1, 0, -1):
    print(star * i + space * (n - i) + space * (n - i) + star * i)
# Out:
# 8
# ★                            ★
# ★★                        ★★
# ★★★                    ★★★
# ★★★★                ★★★★
# ★★★★★            ★★★★★
# ★★★★★★        ★★★★★★
# ★★★★★★★    ★★★★★★★
# ★★★★★★★★★★★★★★★★
# ★★★★★★★    ★★★★★★★
# ★★★★★★        ★★★★★★
# ★★★★★            ★★★★★
# ★★★★                ★★★★
# ★★★                    ★★★
# ★★                        ★★
# ★                            ★

# %%
n = int(input())

for i in range(1, n + 1):
    if i == 1 or i == 2 * n:
        print("*" * n + " " * (2 * (n - 1) - 1) + "*" * n)
    elif i != n:
        print(" " * (i - 1) + "*" + " " * (n - 2) + "*" + " " * (2 * (n - i) - 1) + "*" + " " * (n - 2) + "*")
    else:
        print(" " * (i - 1) + "*" + " " * (n - 2) + "*" + " " * (2 * (n - i) - 1) + " " * (n - 2) + "*")

for i in range(n, 0, -1):
    if i == 1 or i == 2 * n:
        print("*" * n + " " * (2 * (n - 1) - 1) + "*" * n)
    elif i != n:
        print(" " * (i - 1) + "*" + " " * (n - 2) + "*" + " " * (2 * (n - i) - 1) + "*" + " " * (n - 2) + "*")
# Out:
# 4
# ****     ****
#  *  *   *  *
#   *  * *  *
#    *  *  *
#   *  * *  *
#  *  *   *  *
# ****     ****

# %%
n = int(input())
line = n * 2 - 1
star = '\u2605'
space = '  '
for i in range(n, 0, -1):
    if i == n:	## 첫번째 줄은 항상 별이 하나
        print(space * (line // 2), end = '')
        print(star)
    elif i == 1:	## 마지막 줄은 항상 별이 line개
        print(star*line)
    else:	## 나머지
        print(space * (i - 1) + star, end = '' )
        print(space * (line - i * 2) + star)
# Out:
# 5
#         ★
#       ★  ★
#     ★      ★
#   ★          ★
# ★★★★★★★★★

# %%
n = int(input())
star = '\u2605 '	## 별-공백
space = ' '
for i in range(n , 0 , -1):
    print(space * (i - 1), end='')
    print(star * (n - (i - 1)))
# Out:
# 6
#      ★
#     ★ ★
#    ★ ★ ★
#   ★ ★ ★ ★
#  ★ ★ ★ ★ ★
# ★ ★ ★ ★ ★ ★

# %%
n = int(input())
star = '\u2605'
space = ' '

for i in range(n, 0, -1):
    print(space*(i - 1), end = '')
    print(star*(n - (i - 1)))
for i in range(1, n):
    print(space*(i), end='')
    print(star*(n - i))
# Out:
# 5
#     ★
#    ★★
#   ★★★
#  ★★★★
# ★★★★★
#  ★★★★
#   ★★★
#    ★★
#     ★

# %%
n = int(input())
star = '\u2605'
space = ' '

for i in range(n, 0, -1):
    print(space*(i - 1), end = '')
    print(star*(n - (i - 1)))
for i in range(1, n):
    print(space*(i), end='')
    print(star*(n - i))
# Out:
# 8
#        ★
#       ★★
#      ★★★
#     ★★★★
#    ★★★★★
#   ★★★★★★
#  ★★★★★★★
# ★★★★★★★★
#  ★★★★★★★
#   ★★★★★★
#    ★★★★★
#     ★★★★
#      ★★★
#       ★★
#        ★
